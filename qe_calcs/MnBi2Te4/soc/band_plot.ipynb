# %%
import numpy as np
import matplotlib.pyplot as plt
from pythtb import *


import sys
import os

# Adjust the path to point to your project root.
project_root = os.path.abspath('/Users/treycole/Repos/axion-pert')
if project_root not in sys.path:
    sys.path.insert(0, project_root)

from modules.qe_read_file import *

# %%
file_name = "/Users/treycole/Repos/axion-pert/qe_calcs/MnBi2Te4/soc/output/112006bc889/MnBi2Te4.bandsx.out.gnu"

kpts, bands = read_bands_gnu(file_name)

# %%
E_F = 6.8630 # eV

# %%
bands.shape
# Out:
# (200, 151)

# %%
# bands[bands>0].shape[0]/151

# %%
fig, ax = plt.subplots(figsize=(8, 6))

# Plot bands
for band in bands:
    ax.plot(kpts, band, color='b')

ax.set_xlabel('k-path')
ax.set_ylabel('Energy (eV)')
ax.set_title('Band Structure with SOC')
# ax[0].axhline(E_F, linestyle='--', color='gray', lw=0.5)

segments = [50, 50, 50, 1]  # Number of points per segment
labels = [r'$\Gamma$', r'$T$', r'$F_A$', r'$\Gamma$']
xticks, xlabels = get_symmetry_kpath_labels(kpts, segments, labels)

ax.axhline(E_F, linestyle='--', color='gray', lw=0.5)

ax.set_xticks(xticks)
ax.set_xticklabels(xlabels)
for x in xticks:
    ax.axvline(x, color='gray', lw=1, ls='--')

ax.set_xlim(kpts[0], kpts[-1])
ax.set_ylim(-7, 12)
# ax.set_ylim(2, 12)
# Out:
# (-7.0, 12.0)

# %%
kpts
# Out:
# array([ 0.    ,  0.146 ,  0.2921,  0.4381,  0.5842,  0.7302,  0.8763,
#         1.0223,  1.1684,  1.3144,  1.4605,  1.6065,  1.7526,  1.8986,
#         2.0447,  2.1907,  2.3367,  2.4828,  2.6288,  2.7749,  2.9209,
#         3.067 ,  3.213 ,  3.3591,  3.5051,  3.6512,  3.7972,  3.9433,
#         4.0893,  4.2353,  4.3814,  4.5274,  4.6735,  4.8195,  4.9656,
#         5.1116,  5.2577,  5.4037,  5.5498,  5.6958,  5.8419,  5.9879,
#         6.134 ,  6.28  ,  6.426 ,  6.5721,  6.7181,  6.8642,  7.0102,
#         7.1563,  7.3023,  7.3754,  7.4485,  7.5216,  7.5946,  7.6677,
#         7.7408,  7.8139,  7.887 ,  7.9601,  8.0331,  8.1062,  8.1793,
#         8.2524,  8.3255,  8.3985,  8.4716,  8.5447,  8.6178,  8.6909,
#         8.7639,  8.837 ,  8.9101,  8.9832,  9.0563,  9.1293,  9.2024,
#         9.2755,  9.3486,  9.4217,  9.4947,  9.5678,  9.6409,  9.714 ,
#         9.7871,  9.8602,  9.9332, 10.0063, 10.0794, 10.1525, 10.2256,
#        10.2986, 10.3717, 10.4448, 10.5179, 10.591 , 10.664 , 10.7371,
#        10.8102, 10.8833, 10.9564, 11.0828, 11.2093, 11.3357, 11.4621,
#        11.5886, 11.715 , 11.8415, 11.9679, 12.0944, 12.2208, 12.3473,
#        12.4737, 12.6002, 12.7266, 12.8531, 12.9795, 13.106 , 13.2324,
#        13.3589, 13.4853, 13.6117, 13.7382, 13.8646, 13.9911, 14.1175,
#        14.244 , 14.3704, 14.4969, 14.6233, 14.7498, 14.8762, 15.0027,
#        15.1291, 15.2556, 15.382 , 15.5084, 15.6349, 15.7613, 15.8878,
#        16.0142, 16.1407, 16.2671, 16.3936, 16.52  , 16.6465, 16.7729,
#        16.8994, 17.0258, 17.1523, 17.2787])

# %%
len(bands)
# Out:
# 58

# %%
bands[:, 0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 bands[:, 0]
#
# TypeError: list indices must be integers or slices, not tuple

# %% [markdown]
# Hubbard U : 5 eV
# beta : 0.2
# max steps : 300
# New path from paper
# Conv : 1e-6
# DFTD3 Flag for van der Waals correction
# Copy over charge density and XML files from temp using submission script
